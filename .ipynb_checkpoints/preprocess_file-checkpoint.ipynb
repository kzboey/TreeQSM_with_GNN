# %%
import os
import pickle
import numpy as np
import random
import torch
import config
from models import GCN, GIN, GraphSAGE, GatedGCN, AGNN, ARMA
from torch_geometric.explain import Explainer, GNNExplainer

# %%
def getBatchesDataset(path, batchsize=100):
    filebatches = [] # list of filenames
    
    subdirs, dirs, files = os.walk(qsm_path).__next__()
    random.shuffle(files)
    file_length = len(files)
    num_batches = int(np.ceil(file_length/batchsize))
    filebatches = [files[i:i+num_batches] for i in range(0, len(files), num_batches)]
    print(filebatches)
        
qsm_path = './pickle/obj2/'
getBatchesDataset(qsm_path,3)
# Out:
# [['1_2023-01-09_17_2_18_000095.pickle', '1_2023-01-09_17_2_18_000096.pickle', '1_2023-01-09_17_2_18_000092.pickle'], ['1_2023-01-09_17_2_18_000098.pickle', '1_2023-01-09_17_2_18_000091.pickle', '1_2023-01-09_17_2_18_000097.pickle'], ['1_2023-01-09_17_2_18_000090.pickle']]

# %%
data_path = './2023-01-16_44_000327.pickle'
model_path = './models/GatedGCN.pth'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

with open(data_path, 'rb') as f:  
    data = pickle.load(f) 
    
model = GatedGCN(
    in_channel=72, 
    n_convs=config.gated_num_convolutional, 
    dim_h=config.gated_hidden_dimension, 
    top_K=config.gated_topkpooling_ratio, 
    out_channel=37)

checkpoints = torch.load(model_path, map_location=torch.device('cpu'))
model.load_state_dict(checkpoints.state_dict())
model.to(device)
model.eval()
# Out:
# GatedGCN(
#   (gated_layers): ModuleList(
#     (0-1): 2 x GatedGraphConv(128, num_layers=2)
#   )
#   (batch_layer): ModuleList(
#     (0-1): 2 x BatchNorm(128)
#   )
#   (pool_layers): ModuleList(
#     (0): TopKPooling(128, ratio=0.8, multiplier=1.0)
#   )
#   (lin): Linear(in_features=128, out_features=37, bias=True)
# )

# %%
explainer = Explainer(
    model=model,
    algorithm=GNNExplainer(epochs=200),
    explanation_type='model',
    node_mask_type='attributes',
    edge_mask_type='object',
    model_config=dict(
        mode='multiclass_classification',
        task_level='graph',
        return_type='log_probs',  # Model returns log probabilities.
    ),
)

pred = model(data.x, data.edge_index)
explanation = explainer(data.x, data.edge_index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 15>()
#       1 explainer = Explainer(
#       2     model=model,
#       3     algorithm=GNNExplainer(epochs=200),
#    (...)
#      11     ),
#      12 )
#      14 hg, pred = model(data.x, data.edge_index)
# ---> 15 explanation = explainer(data.x, data.edge_index)
#
# File ~/opt/anaconda3/envs/i2dl/lib/python3.10/site-packages/torch_geometric/explain/explainer.py:196, in Explainer.__call__(self, x, edge_index, target, index, **kwargs)
#     192         warnings.warn(
#     193             f"The 'target' should not be provided for the explanation "
#     194             f"type '{self.explanation_type.value}'")
#     195     prediction = self.get_prediction(x, edge_index, **kwargs)
# --> 196     target = self.get_target(prediction)
#     198 if isinstance(index, int):
#     199     index = torch.tensor([index])
#
# File ~/opt/anaconda3/envs/i2dl/lib/python3.10/site-packages/torch_geometric/explain/explainer.py:270, in Explainer.get_target(self, prediction)
#     267     assert False
#     269 if self.model_config.mode == ModelMode.multiclass_classification:
# --> 270     return prediction.argmax(dim=-1)
#     272 return prediction
#
# AttributeError: 'tuple' object has no attribute 'argmax'

# %%
explainer.get_prediction(data.x, data.edge_index)
# Out:
# (tensor([[6.7004e-01, 7.1280e-01, 4.3469e+00, 2.8651e-02, 6.4205e-01, 2.0149e+00,
